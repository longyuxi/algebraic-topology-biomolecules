# %%
# !ls /home/longyuxi/Documents/mount/pdbbind-dataset/refined-set/1a4k
# Out:
# 1a4k_ligand_alpha.pkl
# 1a4k_ligand_feature_alpha_handcrafted.npy
# 1a4k_ligand_feature_ligand_level1_handcrafted.npy
# 1a4k_ligand.mol2
# 1a4k_ligand.sdf
# 1a4k_pocket.pdb
# 1a4k_pocket.pqr
# 1a4k_protein_16.0_chg.npz
# 1a4k_protein_50.0.struct
# 1a4k_protein_alpha.pkl
# 1a4k_protein_feature_complex_alpha_1DCNN.npy
# 1a4k_protein_feature_complex_alpha_2DCNN.npy
# 1a4k_protein_feature_complex_alpha_carbon_ML.npy
# 1a4k_protein_feature_complex_alpha_heavy_ML.npy
# 1a4k_protein_feature_complex_electrostatics_1DCNN.npy
# 1a4k_protein_feature_complex_electrostatics_ML.npy
# 1a4k_protein_feature_complex_interaction_1DCNN.npy
# 1a4k_protein_feature_complex_interaction_ML.npy
# 1a4k_protein.pdb
# 1a4k_protein.pqr

# %%
import pickle
with open('/home/longyuxi/Documents/mount/pdbbind-dataset/refined-set/1fki/1fki_ligand_alpha.pkl', 'rb') as f:
    a = pickle.load(f)

a
# Out:
# {'lig_CCl': [[0, 0.0, 1.2144905],
#   [0, 0.0, 1.1941586],
#   [0, 0.0, 0.7779912],
#   [0, 0.0, 0.7772274],
#   [0, 0.0, 0.7733907],
#   [0, 0.0, 0.7680972],
#   [0, 0.0, 0.7671892],
#   [0, 0.0, 0.7669508],
#   [0, 0.0, 0.7654363],
#   [0, 0.0, 0.7614225],
#   [0, 0.0, 0.761144],
#   [0, 0.0, 0.7599326],
#   [0, 0.0, 0.7597271],
#   [0, 0.0, 0.7595095],
#   [0, 0.0, 0.7592612],
#   [0, 0.0, 0.7582989],
#   [0, 0.0, 0.7581835],
#   [0, 0.0, 0.7577745],
#   [0, 0.0, 0.7569878],
#   [0, 0.0, 0.7544669],
#   [0, 0.0, 0.7531622],
#   [0, 0.0, 0.7526541],
#   [0, 0.0, 0.7514203],
#   [1, 1.222865, 2.606767],
#   [1, 1.22228, 1.4378357],
#   [1, 1.23849, 1.414751],
#   [1, 2.170033, 2.3164334],
#   [1, 2.268166, 2.386987],
#   [1, 2.232624, 2.2700463],
#   [1, 2.388449, 2.4158644],
#   [1, 2.313324, 2.3269222],
#   [2, 2.870566, 2.892689],
#   [2, 2.277058, 2.2900795]],
#  'lig_CNS': [[0, 0.0, 1.1941586],
#   [0, 0.0, 0.7779912],
#   [0, 0.0, 0.7772274],
#   [0, 0.0, 0.7733907],
# ...

# %% [markdown]
# #### need to check if folder contains more than 20 items - if yes, then execution probably didn't finish
